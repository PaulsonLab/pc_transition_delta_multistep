# %%
from process_data import extract_data

# %%
total_points = 2048
lines = 30000
db_path = db_path = './RL_random_cogging.db'

# %%
c, s, p, r = extract_data(db_path, total_points, lines)
# Out:
# ...
# Series e6528e0e-5850-4e03-9796-1d6c5fcc258b:  13%|████▊                               | 20/149 [00:00<00:01, 93.18it/s]
# ...
# ...
# Processing series: 100%|█████████████████████████████████████████████████████████████| 200/200 [11:08<00:00,  3.34s/it]

# %%
print(c.shape)
print(s.shape)
print(p.shape)
print(r.shape)
# Out:
# (29800, 2048, 3)
# (29800, 1)
# (29800, 3)
# (29800, 4)

# %%
import numpy as np
np.savez('./RL_random_cogging_processed.npz', coords=c, steps=s, positions=p, rotations=r)
